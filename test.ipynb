# %%
from brpylib import NevFile, NsxFile
import os
import mne
import tkinter as tk
import tkinter.filedialog

# 选择文件夹
# initialdir = 'F:/ZWQ/anesthesia/anesthesia_profosol' # 默认路径，没有就赋值''
initialdir = ''
if initialdir != '':
    file_path = tk.filedialog.askdirectory(title='选择包含原始数据的文件夹:', initialdir=initialdir)
else:
    file_path = tk.filedialog.askdirectory(title='选择包含原始数据的文件夹:')
    
file_names = os.listdir(file_path)
for file_name_now in file_names.copy():
    if file_name_now[-3:] != 'nev':
        file_names.remove(file_name_now)

file_name = file_names[0]
file_name = file_name[:-4] # delete the suffix

# Read data and header and event
sample_frequencies = [500., 1000., 2000., 10000., 30000., 30000.]
file_type = 2 # 选择用ns几的数据
sample_frequency = sample_frequencies[file_type - 1]

nsx_file = NsxFile(file_path + '/' + file_name + '.ns' + str(file_type))
event_file = NevFile(file_path + '/' + file_name + '.nev')
basic_header = nsx_file.basic_header
extended_header = nsx_file.extended_headers
raw_data = nsx_file.getdata()

channel_names = raw_data['elec_ids']
for i in range(0, len(channel_names)):
    channel_names[i] = str(channel_names[i])
data = raw_data['data'][0]/1e6 # 把μV变成V

events = event_file.getdata()
type(events)
# Out:
# awake_fre2002.ns2 opened
#
# awake_fre2002.nev opened
# dict

# %%
my_events = events['comments']
my_events.keys()
# Out:
# dict_keys(['TimeStamps', 'TimeStampsStarted', 'Data', 'CharSet'])

# %%
len(my_events['TimeStamps'])
# Out:
# 167

# %%
my_events['TimeStamps']
# Out:
# [942551,
#  1081062,
#  1215470,
#  1325330,
#  1460543,
#  1594960,
#  1779424,
#  1956196,
#  2093497,
#  2229732,
#  2389943,
#  2536282,
#  2678851,
#  2790990,
#  2916987,
#  3052320,
#  3196379,
#  3351159,
#  3505939,
#  3657988,
#  3826941,
#  3979923,
#  4155663,
#  4285264,
#  4983943,
#  5153479,
#  5326206,
#  5461214,
#  5599570,
#  5762180,
#  5932790,
#  6059396,
#  6212370,
#  6314395,
#  6456023,
#  6593059,
#  6718756,
#  6884972,
#  7024215,
#  7159104,
#  7276500,
#  7413818,
#  7529390,
#  7673030,
#  7797815,
#  7937663,
#  8080396,
#  8186334,
#  8820812,
#  8973183,
#  9096767,
#  9223952,
#  9350258,
#  9477753,
#  9598627,
#  9746298,
#  9878909,
#  9996177,
#  10167101,
#  10299395,
#  10477361,
#  10605778,
#  10782123,
#  10964767,
#  11137915,
#  11283981,
#  11429535,
#  11554037,
#  11696474,
#  11841917,
#  11977545,
#  12146481,
#  12828900,
#  12959408,
#  13059924,
#  13244998,
#  13386631,
#  13501803,
#  13649055,
#  13750481,
#  13898136,
#  14043871,
#  14186635,
#  14330663,
#  14459991,
#  14612965,
#  14746486,
#  14859532,
#  15014316,
#  15178411,
#  15290084,
#  15456495,
#  15596633,
#  15745370,
#  15879210,
#  16029476,
#  16692140,
#  16846321,
#  17006230,
#  17115779,
#  17250191,
#  17398652,
#  17515911,
#  17654833,
#  17809034,
#  17968608,
#  18100047,
#  18235532,
#  18404485,
#  18547037,
#  18694290,
#  18847571,
#  18950480,
#  19087929,
#  19205189,
#  19356361,
#  19490172,
#  19641649,
#  19772133,
#  19899350,
#  20649588,
#  20815808,
#  20981130,
#  21158666,
#  21321271,
#  21463402,
#  21616186,
#  21761660,
#  21901796,
#  22054168,
#  22186487,
#  22330727,
#  22469372,
#  22571570,
#  22724067,
#  22862289,
#  22998818,
#  23154175,
#  23271146,
#  23423639,
#  23572399,
#  23695982,
#  23848660,
#  23985193,
#  24609132,
#  24718063,
#  24883877,
#  25021920,
#  25161160,
#  25321359,
#  25473425,
#  25611342,
#  25752393,
#  25889834,
#  26025642,
#  26179814,
#  26349055,
#  26491905,
#  26604047,
#  26742996,
#  26885120,
#  26998572,
#  27145534,
#  27296701,
#  27450888,
#  27627639,
#  27743709]

# %%
my_events['Data']
# Out:
# ['cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_3',
#  'cond_1',
#  'cond_2',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_2',
#  'cond_3',
#  'cond_2',
#  'cond_1',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_3',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_3',
#  'cond_3',
#  'cond_1',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_3',
#  'cond_2',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_1',
#  'cond_1',
#  'cond_1',
#  'cond_1',
#  'cond_3',
#  'cond_2',
#  'cond_1',
#  'cond_1',
#  'cond_2',
#  'cond_3',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_3',
#  'cond_2',
#  'cond_3',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_2',
#  'cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_3',
#  'cond_2',
#  'cond_1',
#  'cond_2',
#  'cond_3',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_3',
#  'cond_2',
#  'cond_3',
#  'cond_1',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_2',
#  'cond_3',
#  'cond_1',
#  'cond_1',
#  'cond_1',
#  'cond_2',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_1',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_3',
#  'cond_3',
#  'cond_3',
#  'cond_3',
#  'cond_1',
#  'cond_1',
#  'cond_1',
#  'cond_1',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_2',
#  'cond_3',
#  'cond_1',
#  'cond_2',
#  'cond_1',
#  'cond_3',
#  'cond_1',
#  'cond_2',
#  'cond_3',
#  'cond_2',
#  'cond_3',
#  'cond_3',
#  'cond_1',
#  'cond_1',
#  'cond_3',
#  'cond_3',
#  'cond_2',
#  'cond_2',
#  'cond_1',
#  'cond_3']

# %%
# Write data into mne raw file
mne_info = mne.create_info(ch_names=channel_names, sfreq=sample_frequency, ch_types='ecog')
mne_raw = mne.io.RawArray(data=data, info=mne_info)

save_path = file_path + '/mne_file/'
if not os.path.exists(save_path):
    os.mkdir(save_path)
mne_raw.save(save_path + file_name + '_ns' + str(file_type) + '_raw.fif', overwrite=True)

# Close the files
nsx_file.close()
event_file.close()
